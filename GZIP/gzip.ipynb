# %%
import os
import json
import random
import time
import re
import pickle
import traceback
from tqdm import tqdm
import pandas as pd
import time
import gzip
import numpy as np

# %%
queries = [
    
    "Identify the sentence discussing stage.",
    
    "Identify the sentence discussing histology.",
    
    "Identify the sentence discussing tumor feature.",
    
    "Identify the sentence discussing recurrence."
]

# %%
for q in queries:
    print(q)
    print(q.encode())
# Out:
# Identify the sentence discussing stage.
# b'Identify the sentence discussing stage.'
# Identify the sentence discussing histology.
# b'Identify the sentence discussing histology.'
# Identify the sentence discussing tumor feature.
# b'Identify the sentence discussing tumor feature.'
# Identify the sentence discussing recurrence.
# b'Identify the sentence discussing recurrence.'

# %%
## Functions to process the data
def DataClean(data,labels_path,data_path=None,delete=None):

    print('\n\nImporting and filtering database...')

    if data is not None and not data.empty:
        notes = data
    else:
        notes = pd.read_csv(data_path)

    ints_str = '0123456789-#[]' # characters that usually main categories don't start with

    print('\n\nSplitting each note into sections:\n\n')

    notes_sections = {}

    for note_index in tqdm(range(notes.shape[0])):
        note = notes['text'][note_index].replace('\n\n\n\n','\n').replace('\n\n\n','\n').replace('     ','\n')
        paragraphs = note.split('\n')

        subsections, new_section = [], ' '
        for p in paragraphs:
            line = p.strip()
            if len(line)>0 and ':' in line and not (line[line.find(':')-1] in ints_str) and not(line[0] in ints_str):
                subsections.append([new_section.strip()])
                new_section = p + ' '
            else:
                new_section += p + ' '
        subsections.append([new_section])
        subsections.pop(0)

        note_sect_tit,note_sect_par = [],[]
        for sect in subsections:
            note_sect_tit += [str(*sect)[0:str(*sect).find(':')]]
            note_sect_par += [str(*sect)[str(*sect).find(':')+1:].strip()]
        note_df = pd.DataFrame({'title':note_sect_tit,'category':'','text':note_sect_par, 'label':''})
        notes_sections[notes['note_id'][note_index]] = note_df

    f = open(labels_path, 'r')
    obj_label = f.readlines()
    obj_label_dict = {}
    i = 0
    for s in obj_label:
        i += 1
        if '/' in s:
            buffer = s.strip('\n').lower().split('/')
            for item in buffer:
                obj_label_dict[item] = i
        else:
            obj_label_dict[s.strip('\n').lower()] = i
    f.close()

    for key in tqdm(list(notes_sections.keys())):
        buffer = 'begin_title'
        t = list(notes_sections[key]['title'])
        for idx in range(len(t)):
            for item in list(obj_label_dict.keys()):
                if item in t[idx].lower() and len(t[idx].lower())>2:
                    buffer = item
                    notes_sections[key]['category'][idx] = buffer
                    notes_sections[key]['label'][idx] = obj_label_dict[buffer]
                    break
            notes_sections[key]['category'][idx] = buffer
            notes_sections[key]['label'][idx] = obj_label_dict[buffer]

    notes_sections_output = {}
    row_id  = notes_sections.keys()
    for key in tqdm(row_id):
        buffer = ''
        note_sect_tit, note_sect_par, note_sect_lab = [], [], []
        for i in range(len(notes_sections[key]['category'])):
            if buffer != notes_sections[key]['category'][i]:
                buffer = notes_sections[key]['category'][i]
                note_sect_tit.append(buffer)
                note_sect_lab.append(notes_sections[key]['title'][i])
                note_sect_par.append(notes_sections[key]['text'][i])
                # if buffer == 'followup instruction' or buffer == 'follow up' or buffer == 'follow-up':
                #     break
            else:
                note_sect_par[-1] = note_sect_par[-1] + ' ' + notes_sections[key]['title'][i] + ' ' + notes_sections[key]['text'][i]
        note_df = pd.DataFrame({'title': note_sect_tit, 'text': note_sect_par, 'label': note_sect_lab})
        notes_sections_output[key] = note_df


    notes_sections = notes_sections_output

    if delete != None:
        for key,value in notes_sections.items():
            notes_sections[key] = notes_sections[key][~notes_sections[key]['label'].isin(delete)]

    return notes_sections

# %%
df  = pd.read_csv("malignant_neoplasm_updated_first_100_rows.csv").iloc[:10,]

# %%
NotesSections = DataClean(data=df,
                          labels_path="/Users/sinianzhang/Desktop/LLM/ColBert/ColBERT/labels.txt",
                          delete=['Name','Admission Date','Discharge Date','Date of Birth','Followup Instructions'])
# Out:
# Importing and filtering database...
#
#
# Splitting each note into sections:
# 100%|██████████| 10/10 [00:00<00:00, 1382.75it/s]
# 100%|██████████| 10/10 [00:00<00:00, 413.79it/s]
# 100%|██████████| 10/10 [00:00<00:00, 1188.76it/s]

# %%
def GzipSearch(query,sentences,k):

    distance_from_query = []
    Cq = len(gzip.compress(query.encode()))

    # Loop over the sentences
    for sentence in sentences:
        
        # Compute the length of the compressed string for sentence
        Cs = len(gzip.compress(sentence.encode()))

        # Concatenate query and sentence, and compute the length of the compressed string
        qs = " ".join([query, sentence])
        Cqs = len(gzip.compress(qs.encode()))

        # Compute the Normalized Compression Distance (NCD)
        ncd = (Cqs - min(Cq, Cs)) / max(Cq, Cs)

        # Append the NCD to the list
        distance_from_query.append(ncd)

    # Sort the list and get the indices of the sorted elements
    sorted_idx = np.argsort(np.array(distance_from_query))

    # Get the sentences of the top k nearest neighbors
    top_k_sentences = [sentences[idx] for idx in sorted_idx[:k]]
    
    return top_k_sentences

# %%
Data = {}

for key,value in NotesSections.items():

  Data[key] = {}

  Strings = NotesSections[key]['text'].tolist()

  ## Delete some useless infomation
  paragraphs = [s for s in Strings if s != ""]

  collection = []

  for para in paragraphs:

    Sentences = re.split(r'(?<!\w\.\w.)(?<![A-Z]\.)(?<![A-Z][a-z]\.)(?<! [a-z]\.)(?<![A-Z][a-z][a-z]\.)(?<=\.|\?|\!)\"*\s*\s*(?:\W*)(?<![A-Z])', para)

    collection = collection + [s for s in Sentences if len(s) > 2]

  Data[key]['content'] = ''.join(collection)

  Data[key]['qas'] = []

  for query in queries:

    qas = {}

    print(f"#> {query}")

    # Find the top-k passages for this query
    results = GzipSearch(query,collection,5)
    qas[query] = results
    
    print(results)

    Data[key]['qas'].append(qas)
# Out:
# #> Identify the sentence discussing stage.
# ['The adrenals and spleen are unremarkable.', 'The pancreas is within normal limits.', 'The left kidney is within normal limits.', 'The patient is status post supracervical hysterectomy.', 'No destructive osseous lesions.']
# #> Identify the sentence discussing histology.
# ['The adrenals and spleen are unremarkable.', 'The left kidney is within normal limits.', 'Coronal and sagittal reformations were provided.', 'Multiple pulmonary and hepatic metastases.', 'The patient is status post supracervical hysterectomy.']
# #> Identify the sentence discussing tumor feature.
# ['The adrenals and spleen are unremarkable.', 'Coronal and sagittal reformations were provided.', 'No retroperitoneal or mesenteric adenopathy.', 'New diagnosis of metastatic cancer with unknown primary.', 'The left kidney is within normal limits.']
# #> Identify the sentence discussing recurrence.
# ['The adrenals and spleen are unremarkable.', 'No retroperitoneal or mesenteric adenopathy.', 'The right kidney is otherwise unremarkable.', 'The small and large bowel are unremarkable.', 'The patient is status post supracervical hysterectomy.']
# #> Identify the sentence discussing stage.
# ['The heart size is borderline enlarged.', 'The patient is status post right lower lobectomy.', 'Dyspnea and history of lung cancer.', 'Possible mild pulmonary vascular congestion.', 'This results in crowding of the bronchovascular structures.']
# #> Identify the sentence discussing histology.
# ['Possible mild pulmonary vascular congestion.', 'The patient is status post right lower lobectomy.', 'This results in crowding of the bronchovascular structures.', 'Dyspnea and history of lung cancer.', 'The heart size is borderline enlarged.']
# #> Identify the sentence discussing tumor feature.
# ['The patient is status post right lower lobectomy.', 'The heart size is borderline enlarged.', 'Possible mild pulmonary vascular congestion.', 'This results in crowding of the bronchovascular structures.', 'There may be mild pulmonary vascular congestion.']
# #> Identify the sentence discussing recurrence.
# ['The heart size is borderline enlarged.', 'The patient is status post right lower lobectomy.', 'This results in crowding of the bronchovascular structures.', 'There may be mild pulmonary vascular congestion.', 'Possible mild pulmonary vascular congestion.']
# #> Identify the sentence discussing stage.
# ['The vertebral heights are preserved.', 'Evaluation is slightly limited due to suboptimal IV bolus.', 'The airways are patent to the subsegmental level.', 'No evidence of right heart strain.', 'Shortness of breath, evaluate for pulmonary embolism.']
# #> Identify the sentence discussing histology.
# ['Coronal and sagittal reformations are performed.', 'Evaluation is slightly limited due to suboptimal IV bolus.', 'No focal consolidation or pleural effusion.', 'The airways are patent to the subsegmental level.', 'Shortness of breath, evaluate for pulmonary embolism.']
# #> Identify the sentence discussing tumor feature.
# ['Coronal and sagittal reformations are performed.', 'Right and left MIP reconstructions were performed.', 'The airways are patent to the subsegmental level.', 'An enlarged subcarinal lymph node measuring 1.', 'No focal consolidation or pleural effusion.']
# #> Identify the sentence discussing recurrence.
# ['Coronal and sagittal reformations are performed.', 'The airways are patent to the subsegmental level.', 'No focal consolidation or pleural effusion.', 'No focal consolidation, pleural effusion or pneumothorax.', 'The vertebral heights are preserved.']
# #> Identify the sentence discussing stage.
# ['No evidence of biliary duct obstruction.', 'There is no evidence of ascites or splenomegaly.', 'Extensive diffuse hepatic metastatic disease.', 'Limited views of the kidneys show no hydronephrosis.', 'There is no bile duct dilatation.']
# #> Identify the sentence discussing histology.
# ['There is no evidence of ascites or splenomegaly.', 'Limited views of the kidneys show no hydronephrosis.', 'Extensive diffuse hepatic metastatic disease.', 'No evidence of biliary duct obstruction.', 'There is no bile duct dilatation.']
# #> Identify the sentence discussing tumor feature.
# ['There is no evidence of ascites or splenomegaly.', 'Extensive diffuse hepatic metastatic disease.', 'Limited views of the kidneys show no hydronephrosis.', 'There is no bile duct dilatation.', 'No evidence of biliary duct obstruction.']
# #> Identify the sentence discussing recurrence.
# ['There is no evidence of ascites or splenomegaly.', 'Extensive diffuse hepatic metastatic disease.', 'Limited views of the kidneys show no hydronephrosis.', 'No evidence of biliary duct obstruction.', 'There is no bile duct dilatation.']
# #> Identify the sentence discussing stage.
# ['The gray-white differentiation is preserved.', 'Contiguous axial images were obtained through the brain.', 'No contrast was administered.', 'No acute intracranial process.', 'MRI is more sensitive for evaluation of metastases.']
# #> Identify the sentence discussing histology.
# ['The gray-white differentiation is preserved.', 'Contiguous axial images were obtained through the brain.', 'MRI is more sensitive for evaluation of metastases.', 'No acute intracranial process.', 'The visualized paranasal sinuses and mastoid air cells are well aerated.']
# #> Identify the sentence discussing tumor feature.
# ['MRI is more sensitive for evaluation of metastases.', 'The gray-white differentiation is preserved.', 'Contiguous axial images were obtained through the brain.', 'No acute intracranial process.', 'The visualized paranasal sinuses and mastoid air cells are well aerated.']
# #> Identify the sentence discussing recurrence.
# ['The gray-white differentiation is preserved.', 'Contiguous axial images were obtained through the brain.', 'MRI is more sensitive for evaluation of metastases.', 'No acute intracranial process.', 'The visualized paranasal sinuses and mastoid air cells are well aerated.']
# #> Identify the sentence discussing stage.
# ['Brain abscess status post right craniotomy.', 'There is no shift of normally midline structures.', 'There is no intra or extra-axial hemorrhage.', 'Basal cisterns remain patent.', 'No fracture is identified.']
# #> Identify the sentence discussing histology.
# ['Brain abscess status post right craniotomy.', 'There is no intra or extra-axial hemorrhage.', 'There is no shift of normally midline structures.', 'The previously seen small amount of pneumocephalus has resolved.', 'Ventricles and sulci are normal in size and configuration for age.']
# #> Identify the sentence discussing tumor feature.
# ['Brain abscess status post right craniotomy.', 'There is no shift of normally midline structures.', 'There is no intra or extra-axial hemorrhage.', 'Ventricles and sulci are normal in size and configuration for age.', 'The previously seen small amount of pneumocephalus has resolved.']
# #> Identify the sentence discussing recurrence.
# ['Brain abscess status post right craniotomy.', 'There is no intra or extra-axial hemorrhage.', 'There is no shift of normally midline structures.', 'Ventricles and sulci are normal in size and configuration for age.', 'Basal cisterns remain patent.']
# #> Identify the sentence discussing stage.
# ['CT-guided drainage and catheter repositioning', 'Contrast was injected to confirm catheter placement.', 'The catheter was attached to bag.', 'Subsequently the catheter was advanced further into the patient.', 'After a detailed discussion, informed written consent was obtained.']
# #> Identify the sentence discussing histology.
# ['CT-guided drainage and catheter repositioning', 'Contrast was injected to confirm catheter placement.', 'Samples were sent for microbiology and cytology evaluation.', 'The catheter was secured by a StatLock.', 'Subsequently the catheter was advanced further into the patient.']
# #> Identify the sentence discussing tumor feature.
# ['CT-guided drainage and catheter repositioning', 'Contrast was injected to confirm catheter placement.', 'Samples were sent for microbiology and cytology evaluation.', 'Subsequently the catheter was advanced further into the patient.', 'After a detailed discussion, informed written consent was obtained.']
# #> Identify the sentence discussing recurrence.
# ['CT-guided drainage and catheter repositioning', 'The catheter was secured by a StatLock.', 'Samples were sent for microbiology and cytology evaluation.', 'Contrast was injected to confirm catheter placement.', 'Subsequently the catheter was advanced further into the patient.']
# #> Identify the sentence discussing stage.
# ['Oral contrast was not administered.', 'There is no evidence of mesenteric lymphadenopathy.', 'Continued hydronephrosis may be from residual edema.', 'There is no evidence of vessel thrombosis or occlusion.', 'Adjacent mild stranding is stable.']
# #> Identify the sentence discussing histology.
# ['Continued hydronephrosis may be from residual edema.', 'There is no evidence of mesenteric lymphadenopathy.', 'There is no evidence of vessel thrombosis or occlusion.', 'Oral contrast was not administered.', 'There is no central abdominal adenopathy.']
# #> Identify the sentence discussing tumor feature.
# ['There is no evidence of mesenteric lymphadenopathy.', 'Continued hydronephrosis may be from residual edema.', 'There is no evidence of vessel thrombosis or occlusion.', 'Oral contrast was not administered.', 'There is no central abdominal adenopathy.']
# #> Identify the sentence discussing recurrence.
# ['There is no evidence of mesenteric lymphadenopathy.', 'There is no evidence of vessel thrombosis or occlusion.', 'Continued hydronephrosis may be from residual edema.', 'Oral contrast was not administered.', 'Adjacent mild stranding is stable.']
# #> Identify the sentence discussing stage.
# ['These nodules range in size from 1 to 4 mm.', 'The airways are widely patent to subsegmental level bilaterally.', '45) contains multiple air bronchograms.', 'No destructive or sclerotic bone lesions are present.', 'Degenerative changes throughout the thoracic spine are moderate.']
# #> Identify the sentence discussing histology.
# ['These nodules range in size from 1 to 4 mm.', 'No destructive or sclerotic bone lesions are present.', '45) contains multiple air bronchograms.', 'No previous CT was available for comparison.', '2)Diffuse severe coronary artery calcification.']
# #> Identify the sentence discussing tumor feature.
# ['No destructive or sclerotic bone lesions are present.', 'These nodules range in size from 1 to 4 mm.', '2)Diffuse severe coronary artery calcification.', 'The airways are widely patent to subsegmental level bilaterally.', 'Dense homogeneous consolidation in the right lower lobe (3.']
# #> Identify the sentence discussing recurrence.
# ['No destructive or sclerotic bone lesions are present.', 'These nodules range in size from 1 to 4 mm.', 'Degenerative changes throughout the thoracic spine are moderate.', '45) contains multiple air bronchograms.', '2)Diffuse severe coronary artery calcification.']
# #> Identify the sentence discussing stage.
# ['There has been prior right shoulder surgery.', 'There is a surgical clip in the right groin.', 'There is no free fluid in the pelvis.', 'There is no free air or fluid in the abdomen.', 'Calcification of the coronary arteries is also noted.']
# #> Identify the sentence discussing histology.
# ['There has been prior right shoulder surgery.', 'There is a surgical clip in the right groin.', 'There is no free fluid in the pelvis.', 'Calcification of the coronary arteries is also noted.', 'There is no free air or fluid in the abdomen.']
# #> Identify the sentence discussing tumor feature.
# ['There has been prior right shoulder surgery.', 'There is no free air or fluid in the abdomen.', 'There is a surgical clip in the right groin.', 'Calcification of the coronary arteries is also noted.', 'Airways are patent to the subsegmental level.']
# #> Identify the sentence discussing recurrence.
# ['There has been prior right shoulder surgery.', 'There is no free air or fluid in the abdomen.', 'Airways are patent to the subsegmental level.', 'There is no free fluid in the pelvis.', 'Cholelithiasis without evidence of acute cholecystitis.']

# %%
file_path = 'gzip.json'

with open(file_path, 'w') as file:
    json.dump(Data, file,indent=4)
