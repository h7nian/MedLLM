# %%
import os
import openai
import json
import random
import time
import re
import pickle
import traceback
from transformers import LlamaTokenizer
from tqdm import tqdm
import pandas as pd
openai.api_type = "azure"
openai.api_base = "https://test-openai-celesh.openai.azure.com/"
openai.api_version = "2023-03-15-preview"
openai.api_key = "24a7f6c60aed4aae9c9729229709857b"

# %% [markdown]
# ## Prompt

# %%
inst_prompt = """

\"\"\"
{note}
\"\"\"

Using above patient's discharge summary, you want to ask a well-trained model to help your clinical decision making.
Below are high-level NLP categories that you might want to ask about.
Tell me {num_inst_per_note} different instructions that you will ask to the model.

Tasks :

\"\"\"
{tasks}
\"\"\"

Here are requirements:
1. The words used in the instructions should be diverse to maximize the diversity.
2. A GPT language model should be able to complete the instruction. For example, do not ask the model to create other than any textual output.
3. The question type should be diverse such as one-word answer question, open-ended question, multiple-choice question, and yes/no question.
4. Concat the used NLP categories on front the questions such as  "" (Text Classification) 'The question' "".
"""

ans_prompt = """

\"\"\"
{note}
\"\"\"

Using above patient's discharge summary, answer to the following questions.
The question is given with their own categoreis, with colon-concatenated form.

Here are questions asked in this time:
\"\"\"
{questions}
\"\"\"

Here are requirements:
1. Note that each question is independent.
2. Number your responses.
3. Ensure that each answer is complete and does not raise another question.
4. Answers can span multiple lines if needed.
5. Answer all the questions!
6. Do not anwser additional questions that are not asked in this time!
7. Standardize the terminology used to describe the patient's condition!
8. The output must be in JSON format, Do not add additional information which is not in the JSON format to the output.


format the output in JSON format (with only one key "qas")：

├── "qas"
  └── [i]
      ├── "answers"
      │ 
      ├── "id" 
      │ 
      └── "question"


The top-level key is "qas", which has a value that is a list of elements, denoted by [i]. Each element in the list is an object with three keys: "answers", "id", and "question".

The "answers" key has a value that is a list of elements, denoted by [j]. The element in the list is the answer text to the question. If there are multiple answers or the answers have multiple sections or the answers have multiple sentences in parallel such as `1..., 2..., 3...` ,`A..., B...,C....`,`1)..., 2)..., 3)....` and so on, please divide the whole answer into multiple elements, such as `[section 1 of the answer or answer 1, section 2 of the answer or answer 2, section 3 of the answer or answer 3]`

The "id" key has a value representing the identifier of the question. It can be found in the begining of each question.
"question": This is a string representing the question being asked. Just copy the input question under this key. Include the NLP categories on front in this format "" (Text Classification) 'The question' "".
"""

tasks = [
    "Question Answering",
    "Natural Language Generation",
    "Text Summarization",
    "Text Classification",
    "Temporal Information Extraction",
    "Relation Extraction",
    "Named Entity Recognition",
    "Paraphrasing",
    "Clinical Concept Normalization",
    "Keyword Extraction",
    "Abbreviation expansion",
    "Feature extraction",
    "Content extraction"
]

# %%
question_list = [
    
    "(Text Summarization) What is the patient's primary diagnosis?",
    
    "(Content extraction) Which sentences in the note describe the diagnosis?",
    
    "(Text Summarization) What are the comorbidities of the patient?",
    
    "(Content extraction) Which sentences in the note describe the comorbidities?",
    
    "(Named Entity Recognition) List all the medications mentioned in the discharge summary.",
    
    "(Content extraction) Which sentences in the note describe the medications?",

    "(Named Entity Recognition) List all the labs mentioned in the discharge summary.",

    "(Content extraction) Which sentences in the note describe the labs?",
    
    "(Text Summarization) Provide a brief summary of the history treatment plan for the patient?",

    "(Content extraction) Which sentences in the note describe the history treatment plan for the patient?",
    
    "(Text Summarization) Provide a brief summary of the future treatment plan for the patient?",

    "(Content extraction) Which sentences in the note describe the future treatment plan for the patient?",
    
    "(Content extraction) What medications are the patient currently on?",
    
    "(Text Summarization) List all the diagnoses and determine whether they are from recent onsite visits or past medical history."
    
]

print(len(question_list))
# Out:
# 14

# %%
## Functions to generate prompts 
def generate_inst_prompt(note, num_inst_per_note, sample = True):
    if sample:
        selected_tasks = random.sample(tasks, num_inst_per_note)
    else: selected_tasks = tasks
    
    return [{"role":"system","content":"You are a healthcare professional."},
        {
            "role": "user",
            "content": inst_prompt.format(
                note=note,
                num_inst_per_note=num_inst_per_note,
                tasks="\n".join(selected_tasks),
            ),
        }
    ]

def generate_ans_prompt(note, questions):
    return [
        {"role":"system","content":"You are a healthcare professional."},
        {"role": "user", "content": ans_prompt.format(note=note, questions=questions)}
    ]
    
def generate_con_prompt():
    return [
        {"role":"system","content":"You are a healthcare professional."},
        {"role": "user", "content": "Continue"}
    ]

## Functions to get completion
def get_completion(message,temperature=0.6):
    
    num_tries = 0
    max_num_tries = 5

    while num_tries < max_num_tries:
        try:
            print("try get_completion...")
            response = openai.ChatCompletion.create(
                engine="chat-test",
                messages = message,
                temperature=temperature,
                max_tokens=4096,
                top_p=0.95,
                frequency_penalty=0,
                presence_penalty=0,
                stop=None)
        except Exception as e:
            
            print("-----------------------------------------")
            traceback.print_exc()
            print(f"get_completion Error:",e)
            print("-----------------------------------------")
            
            num_tries += 1
            print(f"Error occurred in get_completion(), retrying (try {num_tries})...")
            time.sleep(5)
            continue
        
        print(f"Success! get_completion() completed. tried {num_tries}")     
        break
    
    if num_tries == max_num_tries:
        print("⚠Error: maximum number of tries reached in function get_completion().") 
        return " "
     
    return response["choices"][0]["message"]["content"]

## Functions to process the questions
def add_question_list(questions, question_list):
    num = len(question_list);temp = ""
    for i in range(len(question_list)):
        temp += str(i + 1) + ". " + question_list[i]+ "\n"
    questions = temp + add_numbers(questions,num)
    return questions

def split_questions(questions,m):
    question_list = re.findall(r'\d+\.\s+[^\d]+', questions)
    question_str = ""
    question_str_list = []
    for i in range(len(question_list)):
        if i % m == 0 and i != 0:
            question_str_list.append(question_str)
            question_str = ""
        question_str += question_list[i] + "\n"
    question_str_list.append(question_str)
    return question_str_list

def find_substring(string):
    start = string.find("{")
    end = string.rfind("}")
    return string[start:end+1]

def add_numbers(string,num):
    pattern = r'\b(\d+)\b'
    replacement = lambda match: str(int(match.group(1)) + num)
    result = re.sub(pattern, replacement, string)
    return result

def get_tokensnum(message,tokenizer):
    
    if type(message) == str:
        return len(tokenizer.tokenize(message))
    else:
        return len(tokenizer.tokenize(message[0]['content'])) + len(tokenizer.tokenize(message[1]['content']))

## Functions to process the data
def DataClean(data,labels_path,data_path=None,write_path=None,delete=None):
    
    print('\n\nImporting and filtering database...')
    
    if data is not None and not data.empty:
        notes = data
    else:
        notes = pd.read_csv(data_path)
        
    ints_str = '0123456789-#[]' # characters that usually main categories don't start with
    
    print('\n\nSplitting each note into sections:\n\n')
    
    notes_sections = {}
    
    for note_index in tqdm(range(notes.shape[0])):
        note = notes['text'][note_index].replace('\n\n\n\n','\n').replace('\n\n\n','\n').replace('     ','\n')
        paragraphs = note.split('\n')
        
        subsections, new_section = [], ' '
        for p in paragraphs:
            line = p.strip()
            if len(line)>0 and ':' in line and not (line[line.find(':')-1] in ints_str) and not(line[0] in ints_str):
                subsections.append([new_section.strip()])
                new_section = p + ' '
            else:
                new_section += p + ' '
        subsections.append([new_section])
        subsections.pop(0)

        note_sect_tit,note_sect_par = [],[]
        for sect in subsections:
            note_sect_tit += [str(*sect)[0:str(*sect).find(':')]]
            note_sect_par += [str(*sect)[str(*sect).find(':')+1:].strip()]
        note_df = pd.DataFrame({'title':note_sect_tit,'category':'','text':note_sect_par, 'label':''})
        notes_sections[notes['note_id'][note_index]] = note_df
    
    f = open(labels_path, 'r')
    obj_label = f.readlines()
    obj_label_dict = {}
    i = 0
    for s in obj_label:
        i += 1
        if '/' in s:
            buffer = s.strip('\n').lower().split('/')
            for item in buffer:
                obj_label_dict[item] = i
        else:
            obj_label_dict[s.strip('\n').lower()] = i
    f.close()

    for key in tqdm(list(notes_sections.keys())):
        buffer = 'begin_title'
        t = list(notes_sections[key]['title'])
        for idx in range(len(t)):
            for item in list(obj_label_dict.keys()):
                if item in t[idx].lower() and len(t[idx].lower())>2:
                    buffer = item
                    notes_sections[key]['category'][idx] = buffer
                    notes_sections[key]['label'][idx] = obj_label_dict[buffer]
                    break
            notes_sections[key]['category'][idx] = buffer
            notes_sections[key]['label'][idx] = obj_label_dict[buffer]

    notes_sections_output = {}
    row_id  = notes_sections.keys()
    for key in tqdm(row_id):
        buffer = ''
        note_sect_tit, note_sect_par, note_sect_lab = [], [], []
        for i in range(len(notes_sections[key]['category'])):
            if buffer != notes_sections[key]['category'][i]:
                buffer = notes_sections[key]['category'][i]
                note_sect_tit.append(buffer)
                note_sect_lab.append(notes_sections[key]['title'][i])
                note_sect_par.append(notes_sections[key]['text'][i])
                # if buffer == 'followup instruction' or buffer == 'follow up' or buffer == 'follow-up':
                #     break
            else:
                note_sect_par[-1] = note_sect_par[-1] + ' ' + notes_sections[key]['title'][i] + ' ' + notes_sections[key]['text'][i]
        note_df = pd.DataFrame({'title': note_sect_tit, 'text': note_sect_par, 'label': note_sect_lab})
        notes_sections_output[key] = note_df


    notes_sections = notes_sections_output
    
    if delete != None:
        for key,value in notes_sections.items():
            notes_sections[key] = notes_sections[key][~notes_sections[key]['label'].isin(delete)]

    if write_path != None:
        f = open(write_path,"wb")
        pickle.dump(notes_sections,f)
        f.close()
    
    return notes_sections

# %% [markdown]
# ## Import Data

# %%
df = pd.read_csv('mimiciv_discharge.csv')

# %%
df = pd.read_csv('mimiciv_discharge.csv')
df = df.loc[[2,5,7,3,8,12,9,19,18,16],].reset_index(drop=True)

tokenizer = LlamaTokenizer.from_pretrained("decapoda-research/llama-7b-hf")
length = df['text'].apply(lambda x: len(tokenizer.tokenize(x)))
# Out:
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'LLaMATokenizer'.
# The class this function is called from is 'LlamaTokenizer'.

# %%
NotesSections = DataClean(data=df,labels_path="labels.txt",write_path="notes.pkl",delete=['Name','Admission Date','Discharge Date','Date of Birth','Followup Instructions'])
# Out:
# 100%|██████████| 10/10 [00:00<00:00, 1744.86it/s]
# 100%|██████████| 10/10 [00:00<00:00, 62.51it/s]
# Importing and filtering database...
#
#
# Splitting each note into sections:
# 100%|██████████| 10/10 [00:00<00:00, 1146.77it/s]

# %%
def SectionSelect(data):
    
    data['temp'] = data['label'] + ": " + data['text']
    while len(tokenizer.tokenize(' '.join(data['temp']))) > 1400:
        random_index = random.randint(0, len(data) - 1)
        data = data.drop(data.index[random_index])
    return ' '.join(data['temp']),{'section_used':data['label'].tolist()}

# %%
for key in NotesSections.keys():
    note,section_used = SectionSelect(NotesSections[key])
    print(len(tokenizer.tokenize(note)))
    print(section_used)
# Out:
# 917
# {'section_used': ['History of Present Illness', 'Brief Hospital Course', 'Discharge Condition']}
# 871
# {'section_used': ['Sex', 'Attending', 'Chief Complaint', 'Major Surgical or Invasive Procedure', 'Review of systems', 'Social History', 'Physical Exam', 'Medications on Admission', 'Discharge Disposition']}
# 1163
# {'section_used': ['Service', 'Allergies', 'Attending', 'History of Present Illness', 'Review of systems', 'Social History', 'Family History', 'Physical Exam', 'Discharge Medications', 'Discharge Disposition', 'Facility', 'Discharge Diagnosis', 'Discharge Condition']}
# 915
# {'section_used': ['Service', 'Attending', 'Major Surgical or Invasive Procedure', 'History of Present Illness', 'Past Medical History', 'Physical Exam', 'Discharge Medications', 'Discharge Disposition', 'Discharge Condition', 'Discharge Instructions']}
# 493
# {'section_used': ['Sex', 'Past Medical History', 'Family History', 'Medications on Admission', 'Facility']}
# 1058
# {'section_used': ['Discharge Medications', 'Facility', 'Discharge Instructions']}
# 1321
# {'section_used': ['Sex', 'Service', 'Allergies', 'Attending', 'Chief Complaint', 'Major Surgical or Invasive Procedure', 'Pertinent Results', 'Medications on Admission', 'Discharge Diagnosis', 'Discharge Condition']}
# 1066
# {'section_used': ['Allergies', 'Chief Complaint', 'Major Surgical or Invasive Procedure', 'Past Medical History', 'Physical Exam', 'Pertinent Results', 'Brief Hospital Course', 'Medications on Admission', 'Discharge Disposition', 'Facility', 'Discharge Diagnosis', 'Discharge Condition', 'Discharge Instructions']}
# 1298
# {'section_used': ['Attending', 'Family History', 'Physical Exam', 'Pertinent Results', 'Brief Hospital Course', 'Medications on Admission', 'Discharge Condition', 'Discharge Instructions']}
# 1324
# {'section_used': ['Allergies', 'History of Present Illness', 'Social History', 'Physical Exam', 'Medications on Admission', 'Discharge Medications', 'Discharge Diagnosis']}

# %%
data = {}
data["version"] = "mimic4"
data["data"] = []
num_tokens = 0
note_record = {}

for row,key in enumerate(NotesSections.keys()):
    
    time.sleep(5)
    print("========================================= row:", row,"=========================================")
    print(time.strftime("%Y-%m-%d %H:%M:%S", time.localtime()))
    
    
    ## Split the note and select the section and record the note
    note_record[key] = []
    note,section_used = SectionSelect(NotesSections[key])
    note_record[key].append(section_used)
    note_record[key].append({"question_record":[]})
    note_record[key].append({"question_error":[]})
    
    n = 16
    
    question_message = generate_inst_prompt(note, num_inst_per_note = n, sample = False)
    num_tokens += get_tokensnum(question_message,tokenizer)
    questions = get_completion(question_message)
    num_tokens += get_tokensnum(questions,tokenizer)
    
    questions = add_question_list(questions, question_list)
    
    print("```")
    print(questions)
    print("```")
    
    m = 5
    question_str_list = split_questions(questions, m)
    
    new_data = {}
    new_data["title"] = df.iloc[row,0]
    new_data["paragraphs"] = [{"context": df.iloc[row,-1], "qas": []}]

    for question_str in question_str_list:
        
        time.sleep(5)
        num_tries = 0
        max_num_tries = 5
        note_record[key][1]["question_record"].append(question_str)
        
        while num_tries < max_num_tries:
            
            try:
                answer_message = generate_ans_prompt(note, question_str)
                num_tokens += get_tokensnum(answer_message,tokenizer)
                answers = get_completion(answer_message)
                num_tokens += get_tokensnum(answers,tokenizer)
                
                print("-----------------------------------------")
                print(answers)
                print("-----------------------------------------")
                new_qas = json.loads(answers)

            except Exception as e:
                
                num_tries += 1
                
                print("-----------------------------------------")
                traceback.print_exc()
                print(f"    Error:",e)
                print("-----------------------------------------")
                
                ## add the continue part
                if "Expecting property name enclosed in double quotes" in str(e):
                    
                    continue_message = generate_con_prompt()
                    num_tokens += get_tokensnum(continue_message,tokenizer)
                    temp = get_completion(continue_message)
                    num_tokens += get_tokensnum(temp,tokenizer)
                    
                    answers = answers + temp
                    print(answers)
                
                else: 
                    
                    print("-----------------------------------------")
                    print(f"    Error occurred in json.loads(), retrying (try {num_tries})...")
                    print("-----------------------------------------")
                    
                    print("-----------------------------------------")
                    print(answers)
                    print("-----------------------------------------")
                    continue
                
            print(f"    Success! json.loads() completed. tried {num_tries}")
            
            if len(new_qas["qas"]) != m:
                num_tries += 1
                print(f"    Error! Answer additional questions. {len(new_qas['qas'])} questions generated, {m} expected. Retrying...")
                continue
            
            for foo in new_qas["qas"]:
                new_data["paragraphs"][0]["qas"].append(foo)
            print(len(new_data["paragraphs"][0]["qas"]))        
            break
        
        if num_tries == max_num_tries:
            print("    ⚠Error: maximum number of tries reached in function json.loads().")
            print(question_str)
            print(answers)
            note_record[key][2]["question_error"].append(question_str)
        
    data["data"].append(new_data)
    print(len(new_data['paragraphs'][0]['qas']))
    print("\n")
    with open('tmp5.json', 'w') as f:      
        json.dump(data, f, indent=2)
    with open('log.json', 'w') as f:      
        json.dump(note_record, f, indent=2)
# Out:
# ========================================= row: 0 =========================================
# 2023-05-29 23:00:46
# try get_completion...
# Success! get_completion() completed. tried 0
# ```
# 1. (Text Summarization) What is the patient's primary diagnosis?
# 2. (Content extraction) Which sentences in the note describe the diagnosis?
# 3. (Text Summarization) What are the comorbidities of the patient?
# 4. (Content extraction) Which sentences in the note describe the comorbidities?
# 5. (Named Entity Recognition) List all the medications mentioned in the discharge summary.
# 6. (Content extraction) Which sentences in the note describe the medications?
# 7. (Named Entity Recognition) List all the labs mentioned in the discharge summary.
# 8. (Content extraction) Which sentences in the note describe the labs?
# 9. (Text Summarization) Provide a brief summary of the history treatment plan for the patient?
# 10. (Content extraction) Which sentences in the note describe the history treatment plan for the patient?
# 11. (Text Summarization) Provide a brief summary of the future treatment plan for the patient?
# 12. (Content extraction) Which sentences in the note describe the future treatment plan for the patient?
# 13. (Content extraction) What medications are the patient currently on?
# 14. (Text Summarization) List all the diagnoses and determine whether they are from recent onsite visits or past medical history.
# 15. (Named Entity Recognition) Identify all the medical conditions mentioned in the patient's history.
# 16. (Text Summarization) Provide a brief summary of the patient's hospital course.
# 17. (Clinical Concept Normalization) Normalize the medical terminology used in the patient's history to standard clinical codes.
# 18. (Relation Extraction) Identify the relationship between the patient's uterine fibroid embolization and the development of a pseudoaneurysm.
# 19. (Keyword Extraction) Extract all the medications prescribed to the patient during her hospital stay.
# 20. (Temporal Information Extraction) Identify the dates of the patient's hospital admission and discharge.
# 21. (Natural Language Generation) Generate a discharge summary for the patient.
# 22. (Abbreviation Expansion) Expand the abbreviation "TTE" used in the patient's history.
# 23. (Feature Extraction) Extract all the symptoms reported by the patient during her hospital stay.
# 24. (Text Classification) Classify the patient's medical conditions as chronic or acute.
# 25. (Relation Extraction) Identify the relationship between the patient's constipation and the medications she was taking.
# 26. (Keyword Extraction) Extract all the instructions given to the patient regarding her medications.
# 27. (Content Extraction) Extract all the diagnostic procedures performed on the patient during her hospital stay.
# 28. (Named Entity Recognition) Identify all the healthcare professionals mentioned in the patient's history.
# 29. (Yes/No Question) Was the patient's pseudoaneurysm successfully treated with thrombin injection?
# 30. (Paraphrasing) Can you rephrase the patient's complaint of "difficulty straightening her right leg without pain"?
# ```
# try get_completion...
# Success! get_completion() completed. tried 0
# -----------------------------------------
# {
#   "qas": [
#     {
#       "question": "(Text Summarization) What is the patient's primary diagnosis?",
#       "id": 1,
#       "answers": [
#         "The patient's primary diagnosis is right groin pseudoaneurysm."
#       ]
#     },
#     {
#       "question": "(Content extraction) Which sentences in the note describe the diagnosis?",
#       "id": 2,
#       "answers": [
#         "Patient was found by ultrasound to have a right groin pseudoaneurysm.",
#         "Patient presented with psuedoaneurysm confirmed by ultrasound that was secondary to her recent uterine fibroid embolization.",
#         "Ultrasound on ___ indicated pseudoaneurysm had been thrombosed with remaining femoral artery patent.",
#         "A repeat US on ___ prior to discharge also demonstrated thrombosed right femoral artery pseudoaneurysm and patent right common and superficial femoral arteries and veins."
#       ]
#     },
#     {
#       "question": "(Text Summarization) What are the comorbidities of the patient?",
#       "id": 3,
#       "answers": [
#         "The patient has rheumatoid arthritis and irritable bowel syndrome."
#       ]
#     },
#     {
#       "question": "(Content extraction) Which sentences in the note describe the comorbidities?",
#       "id": 4,
#       "answers": [
#         "Past Medical History: 1. Rheumatoid Arthrits 2. Irritable Bowel Syndrome 3. Bicuspid aortic valve (no TTE in chart).",
#         "Patient reports that she has irritable bowel syndrome with constipation at baseline.",
#         "Rheumatoid Arthritis:Stable during this admission. Patient was continued on outpatient regimen of prednisone and folate. Patient had taken weekly dose of methotrexate prior to admission."
#       ]
#     },
#     {
#       "question": "(Named Entity Recognition) List all the medications mentioned in the discharge summary.",
#       "id": 5,
#       "answers": [
#         "Prednisone",
#         "Folate",
#         "Methotrexate",
#         "Culturale (probiotic) daily",
#         "Oxycodone",
#         "Ibuprofen"
#       ]
#     },
#     {
#       "question": "(Content extraction) Which sentences in the note describe the medications?",
#       "id": 6,
#       "answers": [
#         "Medications on Admission: 1. Prednisone 5mg QDAY 2. Folate 1 mg QDAY 3. Methotrexate 10mg Q wk 4. Culturale (probiotic) daily",
#         "Pain initially treated with intravenous morphine and transitioned to oral oxycodone at time of discharge. She was given a prescription for oxycodone 5mg ___ tabs TID as needed for pain. She was instructed not to drive or operate heavy machinery while taking this medication. She was also prescribed ibuprofen 800 mg PO TID to reduce inflammation and instructed to take this medication with food and water.",
#         "Patient was continued on outpatient regimen of prednisone and folate. Patient had taken weekly dose of methotrexate prior to admission."
#       ]
#     },
#     {
#       "question": "(Named Entity Recognition) List all the labs mentioned in the discharge summary.",
#       "id": 7,
#       "answers": [
#         "None mentioned."
#       ]
#     },
#     {
#       "question": "(Content extraction) Which sentences in the note describe the labs?",
#       "id": 8,
#       "answers": [
#         "None mentioned."
#       ]
#     },
#     {
#       "question": "(Text Summarization) Provide a brief summary of the history treatment plan for the patient?",
#       "id": 9,
#       "answers": [
#         "The patient was admitted for thrombin injection of pseudoaneurysm. Pain initially treated with intravenous morphine and transitioned to oral oxycodone at time of discharge. She was given a prescription for oxycodone 5mg ___ tabs TID as needed for pain. She was instructed not to drive or operate heavy machinery while taking this medication. She was also prescribed ibuprofen 800 mg PO TID to reduce inflammation and instructed to take this medication with food and water. Patient experienced constipation during this admission and was started on bowel regimen including colace, senna, and lactulose."
#       ]
#     },
#     {
#       "question": "(Content extraction) Which sentences in the note describe the history treatment plan for the patient?",
#       "id": 10,
#       "answers": [
#         "Patient was admitted for thrombin injection of pseudoaneurysm. Pain initially treated with intravenous morphine and transitioned to oral oxycodone at time of discharge. She was given a prescription for oxycodone 5mg ___ tabs TID as needed for pain. She was instructed not to drive or operate heavy machinery while taking this medication. She was also prescribed ibuprofen 800 mg PO TID to reduce inflammation and instructed to take this medication with food and water.",
#         "Patient experienced constipation during this admission. Last bowel movement day prior to admission. Likely constipation worsened due to patient taking narcotics for pain control. Patient started on bowel regimen including colace, senna, and lactulose. Patient was discharged with a prescription for oral lactulose. She will contact her primary care physician if she is unable to have a bowel movement within ___ hours of discharge."
#       ]
#     }
#   ]
# }
# -----------------------------------------
#     Success! json.loads() completed. tried 0
# 10
# try get_completion...
# -----------------------------------------
# get_completion Error: Requests to the Creates a completion for the chat message Operation under Azure OpenAI API version 2023-03-15-preview have exceeded token rate limit of your current OpenAI S0 pricing tier. Please retry after 3 seconds. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit.
# -----------------------------------------
# Error occurred in get_completion(), retrying (try 1)...
# Traceback (most recent call last):
#   File "/var/folders/nt/61qr68k1095348fy48d1yhf80000gp/T/ipykernel_37696/2648004828.py", line 39, in get_completion
#     response = openai.ChatCompletion.create(
#   File "/Users/sinianzhang/opt/anaconda3/lib/python3.9/site-packages/openai/api_resources/chat_completion.py", line 25, in create
#     return super().create(*args, **kwargs)
#   File "/Users/sinianzhang/opt/anaconda3/lib/python3.9/site-packages/openai/api_resources/abstract/engine_api_resource.py", line 153, in create
#     response, _, api_key = requestor.request(
#   File "/Users/sinianzhang/opt/anaconda3/lib/python3.9/site-packages/openai/api_requestor.py", line 230, in request
#     resp, got_stream = self._interpret_response(result, stream)
#   File "/Users/sinianzhang/opt/anaconda3/lib/python3.9/site-packages/openai/api_requestor.py", line 624, in _interpret_response
#     self._interpret_response_line(
#   File "/Users/sinianzhang/opt/anaconda3/lib/python3.9/site-packages/openai/api_requestor.py", line 687, in _interpret_response_line
#     raise self.handle_error_response(
# openai.error.RateLimitError: Requests to the Creates a completion for the chat message Operation under Azure OpenAI API version 2023-03-15-preview have exceeded token rate limit of your current OpenAI S0 pricing tier. Please retry after 3 seconds. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit.
# try get_completion...
# Success! get_completion() completed. tried 1
# -----------------------------------------
# {
#   "qas": [
#     {
#       "question": "(Text Summarization) Provide a brief summary of the future treatment plan for the patient?",
#       "answers": [
#         "The patient will have post-procedure follow-up arranged by interventional radiology, and she has been discharged with prescriptions for oxycodone and ibuprofen to manage pain. She has also been prescribed lactulose to manage constipation.",
#         "The future treatment plan for the patient includes post-procedure follow-up, prescriptions for pain management and constipation, and instructions to contact her primary care physician if she is unable to have a bowel movement within a certain timeframe."
#       ],
#       "id": 11
#     },
#     {
#       "question": "(Content extraction) Which sentences in the note describe the future treatment plan for the patient?",
#       "answers": [
#         "Post-procedure follow up to be arranged by ___,  interventional radiology ___.  ",
#         "Following thrombin injection patient  experienced right groin pain. She also experienced pain in her  pelvic region thought to be secondary to fibroids responding to  embolization procedure. Pain initially treated with intravenous  morphine and transitioned to oral oxycodone at time of  discharge. She was given a prescription for oxycodone 5mg ___  tabs TID as needed for pain. She was instructed not to drive or  operate heavy machinery while taking this medication. She was  also prescribed ibuprofen 800 mg PO TID to reduce inflammation  and instructed to take this medication with food and water. ",
#         "Patient experienced constipation during this  admission. Last bowel movement day prior to admission. Patient  reports that she has irritable bowel syndrome with constipation  at baseline. Likely constipation worsened due to patient taking  narcotics for pain control. Patient started on bowel regimen  including colace, senna and lactulose. Patient was discharged  with a prescription for oral lactulose. She will contact her  primary care physician if she is unable to have a bowel movement  within ___ hours of discharge.  "
#       ],
#       "id": 12
#     },
#     {
#       "question": "(Content extraction) What medications are the patient currently on?",
#       "answers": [
#         "1. Prednisone 5mg QDAY",
#         "2. Folate 1 mg QDAY",
#         "3. Methotrexate 10mg Q wk",
#         "4. Culturale (probiotic) daily",
#         "5. Oxycodone 5mg TID as needed for pain",
#         "6. Ibuprofen 800mg PO TID for inflammation",
#         "7. Lactulose for constipation"
#       ],
#       "id": 13
#     },
#     {
#       "question": "(Text Summarization) List all the diagnoses and determine whether they are from recent onsite visits or past medical history.",
#       "answers": [
#         "Diagnoses:",
#         "1. Rheumatoid Arthritis (past medical history)",
#         "2. Irritable Bowel Syndrome (past medical history)",
#         "3. Bicuspid aortic valve (no TTE in chart) (past medical history)",
#         "4. Right groin pseudoaneurysm (recent onsite visit)",
#         "5. Fibroids (recent onsite visit)"
#       ],
#       "id": 14
#     },
#     {
#       "question": "(Named Entity Recognition) Identify all the medical conditions mentioned in the patient's history.",
#       "answers": [
#         "1. Rheumatoid Arthritis",
#         "2. Irritable Bowel Syndrome",
#         "3. Bicuspid aortic valve",
#         "4. Right groin pseudoaneurysm",
#         "5. Fibroids"
#       ],
#       "id": 15
#     },
#     {
#       "question": "(Text Summarization) Provide a brief summary of the patient's hospital course.",
#       "answers": [
#         "The patient was admitted after experiencing right groin pain and swelling, which was determined to be a pseudoaneurysm. She had undergone uterine fibroid embolization prior to admission. The pseudoaneurysm was treated with thrombin injection, and the patient was given medication to manage her pain and constipation. She was discharged with instructions to follow up with interventional radiology, and to contact her primary care physician if she experienced any issues with constipation.",
#         "The patient presented with a pseudoaneurysm resulting from uterine fibroid embolization, which was treated with thrombin injection. She experienced pain and constipation during her hospital stay, and was discharged with medication and follow-up instructions."
#       ],
#       "id": 16
#     },
#     {
#       "question": "(Clinical Concept Normalization) Normalize the medical terminology used in the patient's history to standard clinical codes.",
#       "answers": [
#         "1. Rheumatoid Arthritis - M05.9",
#         "2. Irritable Bowel Syndrome - K58.0",
#         "3. Bicuspid aortic valve - Q23.1",
#         "4. Right groin pseudoaneurysm - I77.81",
#         "5. Fibroids - D25.9"
#       ],
#       "id": 17
#     },
#     {
#       "question": "(Relation Extraction) Identify the relationship between the patient's uterine fibroid embolization and the development of a pseudoaneurysm.",
#       "answers": [
#         "The patient's uterine fibroid embolization was the cause of her development of a right groin pseudoaneurysm."
#       ],
#       "id": 18
#     },
#     {
#       "question": "(Keyword Extraction) Extract all the medications prescribed to the patient during her hospital stay.",
#       "answers": [
#         "1. Prednisone",
#         "2. Folate",
#         "3. Methotrexate",
#         "4. Culturale (probiotic)",
#         "5. Oxycodone",
#         "6. Ibuprofen",
#         "7. Lactulose"
#       ],
#       "id": 19
#     },
#     {
#       "question": "(Temporal Information Extraction) Identify the dates of the patient's hospital admission and discharge.",
#       "answers": [
#         "There is no information about the dates of the patient's hospital admission and discharge in the given note."
#       ],
#       "id": 20
#     }
#   ]
# }
# -----------------------------------------
#     Success! json.loads() completed. tried 0
# 20
# try get_completion...
# Success! get_completion() completed. tried 0
# -----------------------------------------
# {
#   "qas": [
#     {
#       "answers": [
#         "This is a 58 year old female who presented with a right groin pseudoaneurysm following a uterine fibroid embolization. She was treated with thrombin injection and discharged home with pain medications and follow-up appointments with her interventional radiologist and primary care physician. She was also given instructions regarding constipation management."
#       ],
#       "id": "21",
#       "question": "(Natural Language Generation) Generate a discharge summary for the patient."
#     },
#     {
#       "answers": [
#         "Transthoracic echocardiogram"
#       ],
#       "id": "22",
#       "question": "(Abbreviation Expansion) Expand the abbreviation \"TTE\" used in the patient's history."
#     },
#     {
#       "answers": [
#         "right groin pain, right groin swelling, pain radiating across lower abdomen"
#       ],
#       "id": "23",
#       "question": "(Feature Extraction) Extract all the symptoms reported by the patient during her hospital stay."
#     },
#     {
#       "answers": [
#         "Chronic: Rheumatoid Arthritis, Irritable Bowel Syndrome, Bicuspid aortic valve",
#         "Acute: Right groin pseudoaneurysm"
#       ],
#       "id": "24",
#       "question": "(Text Classification) Classify the patient's medical conditions as chronic or acute."
#     },
#     {
#       "answers": [
#         "The patient's constipation was likely worsened due to the narcotics she was taking for pain control."
#       ],
#       "id": "25",
#       "question": "(Relation Extraction) Identify the relationship between the patient's constipation and the medications she was taking."
#     },
#     {
#       "answers": [
#         "The patient was given a prescription for oxycodone 5mg tablets to take as needed for pain, but was instructed not to drive or operate heavy machinery while taking this medication. She was also prescribed ibuprofen 800mg to take three times a day with food and water. Additionally, she was started on a bowel regimen including colace, senna, and lactulose, and was discharged with a prescription for oral lactulose. She was instructed to contact her primary care physician if she was unable to have a bowel movement within a certain number of hours after discharge."
#       ],
#       "id": "26",
#       "question": "(Keyword Extraction) Extract all the instructions given to the patient regarding her medications."
#     },
#     {
#       "answers": [
#         "ultrasound"
#       ],
#       "id": "27",
#       "question": "(Content Extraction) Extract all the diagnostic procedures performed on the patient during her hospital stay."
#     },
#     {
#       "answers": [
#         "interventional radiology physician's assistant"
#       ],
#       "id": "28",
#       "question": "(Named Entity Recognition) Identify all the healthcare professionals mentioned in the patient's history."
#     },
#     {
#       "answers": [
#         "Yes"
#       ],
#       "id": "29",
#       "question": "(Yes/No Question) Was the patient's pseudoaneurysm successfully treated with thrombin injection?"
#     },
#     {
#       "answers": [
#         "The patient experienced pain when trying to straighten her right leg."
#       ],
#       "id": "30",
#       "question": "(Paraphrasing) Can you rephrase the patient's complaint of \"difficulty straightening her right leg without pain\"?"
#     }
#   ]
# }
# -----------------------------------------
#     Success! json.loads() completed. tried 0
# 30
# 30
#
#
# ========================================= row: 1 =========================================
# 2023-05-29 23:02:22
# try get_completion...
# Success! get_completion() completed. tried 0
# ```
# 1. (Text Summarization) What is the patient's primary diagnosis?
# 2. (Content extraction) Which sentences in the note describe the diagnosis?
# 3. (Text Summarization) What are the comorbidities of the patient?
# 4. (Content extraction) Which sentences in the note describe the comorbidities?
# 5. (Named Entity Recognition) List all the medications mentioned in the discharge summary.
# 6. (Content extraction) Which sentences in the note describe the medications?
# 7. (Named Entity Recognition) List all the labs mentioned in the discharge summary.
# 8. (Content extraction) Which sentences in the note describe the labs?
# 9. (Text Summarization) Provide a brief summary of the history treatment plan for the patient?
# 10. (Content extraction) Which sentences in the note describe the history treatment plan for the patient?
# 11. (Text Summarization) Provide a brief summary of the future treatment plan for the patient?
# 12. (Content extraction) Which sentences in the note describe the future treatment plan for the patient?
# 13. (Content extraction) What medications are the patient currently on?
# 14. (Text Summarization) List all the diagnoses and determine whether they are from recent onsite visits or past medical history.
# 15. (Question Answering) What was the patient's chief complaint?
# 16. (Text Summarization) Can you summarize the patient's medical history in a few sentences?
# 17. (Named Entity Recognition) Can you identify all the medical conditions mentioned in the discharge summary?
# 18. (Temporal Information Extraction) When did the patient move into the assisted living facility?
# 19. (Relation Extraction) Is there any relation between the patient's CHF and Afib?
# 20. (Keyword Extraction) What are the keywords that describe the patient's current condition?
# 21. (Abbreviation Expansion) What does TTE stand for in the discharge summary?
# 22. (Feature Extraction) What are the significant findings from the patient's lower extremity ultrasound?
# 23. (Content Extraction) Can you extract the patient's vital signs from the discharge summary?
# 24. (Natural Language Generation) Can you generate a summary of the patient's hospitalization and discharge instructions?
# 25. (Text Classification) What type of medical care is the patient being discharged to?
# 26. (Temporal Information Extraction) When was the patient's last bowel movement?
# 27. (Relation Extraction) Is there any relation between the patient's shortness of breath and the pleural effusions?
# 28. (Named Entity Recognition) Can you identify any medications mentioned in the discharge summary?
# 29. (Paraphrasing) Can you rephrase the sentence "We decided to focus on your comfort" in a different way?
# 30. (Yes/No Question) Was the patient diagnosed with a fracture in the hip X-ray?
# ```
# try get_completion...
# Success! get_completion() completed. tried 0
# -----------------------------------------
# {
#   "qas": [
#     {
#       "answers": [
#         "right hip pain"
#       ],
#       "id": "1",
#       "question": "(Text Summarization) What is the patient's primary diagnosis?"
#     },
#     {
#       "answers": [
#         "___ is a ___ y/o F with PMHx CHF, Afib not on  anticoagulation, severe advanced Alzheimer's dementia,  osteoporosis, HTN, who presents from assisted living facility  with R hip pain. She has worsening memory function, now with severe short term  memory loss. Decreased appetite and PO intake. She was recently  seen in ___ clinic by Dr. ___ new diagnosis of CHF. She underwent an TTE at ___ yesterday ___ to evaluate her  systolic function. Labs were significant for  K 2.8  Cr 0.8 CBC 13.9/12.5/39.2/168 UA WBC 22, moderate leuks, negative nitrites. CXR Bilateral pleural effusions, large on the right and small on the  left. No definite focal consolidation identified, although  evaluation is limited secondary to these effusions. Lower extremity ultrasound 1. Deep vein thrombosis of the left  common femoral vein extending into at least the popliteal vein.  Left calf veins were not clearly identified and possibly also  occluded.",
#         "right hip pain",
#         "PMHx CHF, Afib not on  anticoagulation, severe advanced Alzheimer's dementia,  osteoporosis, HTN, worsening memory function, now with severe short term  memory loss, decreased appetite and PO intake, new diagnosis of CHF, K 2.8  Cr 0.8 CBC 13.9/12.5/39.2/168 UA WBC 22, moderate leuks, negative nitrites, Bilateral pleural effusions, large on the right and small on the  left, Lower extremity ultrasound 1. Deep vein thrombosis of the left  common femoral vein extending into at least the popliteal vein.  Left calf veins were not clearly identified and possibly also  occluded."
#       ],
#       "id": "2",
#       "question": "(Content extraction) Which sentences in the note describe the diagnosis?"
#     },
#     {
#       "answers": [
#         "CHF, Afib, Alzheimer's dementia, osteoporosis, HTN"
#       ],
#       "id": "3",
#       "question": "(Text Summarization) What are the comorbidities of the patient?"
#     },
#     {
#       "answers": [
#         "___ is a ___ y/o F with PMHx CHF, Afib not on  anticoagulation, severe advanced Alzheimer's dementia,  osteoporosis, HTN, She has worsening memory function, now with severe short term  memory loss. Decreased appetite and PO intake. She was recently  seen in ___ clinic by Dr. ___ new diagnosis of CHF.",
#         "CHF, Afib not on  anticoagulation, severe advanced Alzheimer's dementia,  osteoporosis, HTN"
#       ],
#       "id": "4",
#       "question": "(Content extraction) Which sentences in the note describe the comorbidities?"
#     },
#     {
#       "answers": [
#         "80 mEq of K",
#         "60mg Enoxaparin Sodium"
#       ],
#       "id": "5",
#       "question": "(Named Entity Recognition) List all the medications mentioned in the discharge summary?"
#     },
#     {
#       "answers": [
#         "She was given 80 mEq of K and 60mg Enoxaparin Sodium."
#       ],
#       "id": "6",
#       "question": "(Content extraction) Which sentences in the note describe the medications?"
#     },
#     {
#       "answers": [
#         "K",
#         "Cr",
#         "CBC",
#         "UA"
#       ],
#       "id": "7",
#       "question": "(Named Entity Recognition) List all the labs mentioned in the discharge summary?"
#     },
#     {
#       "answers": [
#         "Labs were significant for  K 2.8  Cr 0.8 CBC 13.9/12.5/39.2/168 UA WBC 22, moderate leuks, negative nitrites."
#       ],
#       "id": "8",
#       "question": "(Content extraction) Which sentences in the note describe the labs?"
#     },
#     {
#       "answers": [
#         "The patient was hospitalized with right hip pain. A blood clot was found in the left leg and noticed that  the heart wasn't pumping very efficiently. The patient and family decided to focus on comfort. Because of this, the patient was discharged to ___ for hospice care."
#       ],
#       "id": "9",
#       "question": "(Text Summarization) Provide a brief summary of the history treatment plan for the patient?"
#     },
#     {
#       "answers": [
#         "We decided to focus on your comfort. Because of this,  you are being discharged to ___ for hospice care."
#       ],
#       "id": "10",
#       "question": "(Content extraction) Which sentences in the note describe the history treatment plan for the patient?"
#     }
#   ]
# }
# -----------------------------------------
#     Success! json.loads() completed. tried 0
# 10
# try get_completion...
# Success! get_completion() completed. tried 0
# -----------------------------------------
# {
#   "qas": [
#     {
#       "question": "(Text Summarization) Provide a brief summary of the future treatment plan for the patient?",
#       "id": 11,
#       "answers": [
#         "The patient is being discharged to hospice care to focus on her comfort."
#       ]
#     },
#     {
#       "question": "(Content extraction) Which sentences in the note describe the future treatment plan for the patient?",
#       "id": 12,
#       "answers": [
#         "Discharge Instructions: Dear ___,   It was a pleasure taking care of you during your  hospitalization. Briefly, you were hospitalized with right hip  pain. We did Xrays of your hip which did not show any fractures.  We also found a blood clot in your left leg and noticed that  your heart wasn't pumping very efficiently. We talked with you  and your family, who shared with us many of your wishes about  being hospitalized and the type of care you would like to  receive. We decided to focus on your comfort. Because of this,  you are being discharged to ___ for hospice care.     We wish you and your family the ___,   Your ___ Treatment Team"
#       ]
#     },
#     {
#       "question": "(Content extraction) What medications are the patient currently on?",
#       "id": 13,
#       "answers": [
#         "The note does not provide information on the medications the patient is currently on."
#       ]
#     },
#     {
#       "question": "(Text Summarization) List all the diagnoses and determine whether they are from recent onsite visits or past medical history.",
#       "id": 14,
#       "answers": [
#         "Diagnoses: Right hip pain, deep vein thrombosis of the left  common femoral vein, CHF, Afib, bilateral pleural effusions.",
#         "It is not specified whether the diagnoses are from recent onsite visits or past medical history."
#       ]
#     },
#     {
#       "question": "(Question Answering) What was the patient's chief complaint?",
#       "id": 15,
#       "answers": [
#         "The patient's chief complaint was right hip pain."
#       ]
#     },
#     {
#       "question": "(Text Summarization) Can you summarize the patient's medical history in a few sentences?",
#       "id": 16,
#       "answers": [
#         "The patient has a history of CHF, Afib not on anticoagulation, severe advanced Alzheimer's dementia, osteoporosis, and HTN. She was recently diagnosed with CHF and underwent a TTE to evaluate her systolic function. She also had an ICU course for an allergic reaction to a medication."
#       ]
#     },
#     {
#       "question": "(Named Entity Recognition) Can you identify all the medical conditions mentioned in the discharge summary?",
#       "id": 17,
#       "answers": [
#         "The medical conditions mentioned in the discharge summary are right hip pain, deep vein thrombosis of the left common femoral vein, CHF, Afib, and bilateral pleural effusions."
#       ]
#     },
#     {
#       "question": "(Temporal Information Extraction) When did the patient move into the assisted living facility?",
#       "id": 18,
#       "answers": [
#         "The note does not provide the exact date when the patient moved into the assisted living facility. However, it mentions that she moved in given worsening of her dementia, after developing acute SOB with ambulation in an unspecified date, and was seen in a clinic by Dr. ___ after her hospitalization for CHF."
#       ]
#     },
#     {
#       "question": "(Relation Extraction) Is there any relation between the patient's CHF and Afib?",
#       "id": 19,
#       "answers": [
#         "The note does not provide information on the relation between the patient's CHF and Afib."
#       ]
#     },
#     {
#       "question": "(Keyword Extraction) What are the keywords that describe the patient's current condition?",
#       "id": 20,
#       "answers": [
#         "The keywords that describe the patient's current condition are right hip pain, deep vein thrombosis, CHF, Afib, pleural effusions, Alzheimer's dementia, osteoporosis, and deconditioning."
#       ]
#     }
#   ]
# }
# -----------------------------------------
#     Success! json.loads() completed. tried 0
# 20
# try get_completion...
# Success! get_completion() completed. tried 0
# -----------------------------------------
# {
#   "qas": [
#     {
#       "answers": [
#         "transthoracic echocardiography"
#       ],
#       "id": "21",
#       "question": "(Abbreviation Expansion) What does TTE stand for in the discharge summary?"
#     },
#     {
#       "answers": [
#         [
#           "1. Deep vein thrombosis of the left common femoral vein extending into at least the popliteal vein.",
#           "2. No DVT in the right lower extremity."
#         ]
#       ],
#       "id": "22",
#       "question": "(Feature Extraction) What are the significant findings from the patient's lower extremity ultrasound?"
#     },
#     {
#       "answers": [
#         [
#           "Initial vitals were 98.7, 96, 122/48, 20, 96% RA.",
#           "Vitals on transfer were 97.9, 79, 125/53, 18, 100% Nasal Cannula."
#         ]
#       ],
#       "id": "23",
#       "question": "(Content Extraction) Can you extract the patient's vital signs from the discharge summary?"
#     },
#     {
#       "answers": [
#         "The patient was hospitalized with right hip pain and was found to have a blood clot in her left leg, as well as decreased heart function. The decision was made to focus on the patient's comfort, and she is being discharged to hospice care."
#       ],
#       "id": "24",
#       "question": "(Natural Language Generation) Can you generate a summary of the patient's hospitalization and discharge instructions?"
#     },
#     {
#       "answers": [
#         "hospice care"
#       ],
#       "id": "25",
#       "question": "(Text Classification) What type of medical care is the patient being discharged to?"
#     },
#     {
#       "answers": [
#         "She has not had a bowel movement in 2 days."
#       ],
#       "id": "26",
#       "question": "(Temporal Information Extraction) When was the patient's last bowel movement?"
#     },
#     {
#       "answers": [
#         "Yes, the patient has bilateral pleural effusions, with a large effusion on the right and a small effusion on the left. It is unclear if there is a relation between the pleural effusions and the patient's shortness of breath."
#       ],
#       "id": "27",
#       "question": "(Relation Extraction) Is there any relation between the patient's shortness of breath and the pleural effusions?"
#     },
#     {
#       "answers": [
#         [
#           "Enoxaparin Sodium",
#           "Zofran"
#         ]
#       ],
#       "id": "28",
#       "question": "(Named Entity Recognition) Can you identify any medications mentioned in the discharge summary?"
#     },
#     {
#       "answers": [
#         "The decision was made to prioritize the patient's comfort."
#       ],
#       "id": "29",
#       "question": "(Paraphrasing) Can you rephrase the sentence 'We decided to focus on your comfort' in a different way?"
#     },
#     {
#       "answers": [
#         "No, the Xrays of the hip did not show any fractures."
#       ],
#       "id": "30",
#       "question": "(Yes/No Question) Was the patient diagnosed with a fracture in the hip X-ray?"
#     }
#   ]
# }
# -----------------------------------------
#     Success! json.loads() completed. tried 0
# 30
# 30
#
#
# ========================================= row: 2 =========================================
# 2023-05-29 23:03:45
# try get_completion...
# Success! get_completion() completed. tried 0
# ```
# 1. (Text Summarization) What is the patient's primary diagnosis?
# 2. (Content extraction) Which sentences in the note describe the diagnosis?
# 3. (Text Summarization) What are the comorbidities of the patient?
# 4. (Content extraction) Which sentences in the note describe the comorbidities?
# 5. (Named Entity Recognition) List all the medications mentioned in the discharge summary.
# 6. (Content extraction) Which sentences in the note describe the medications?
# 7. (Named Entity Recognition) List all the labs mentioned in the discharge summary.
# 8. (Content extraction) Which sentences in the note describe the labs?
# 9. (Text Summarization) Provide a brief summary of the history treatment plan for the patient?
# 10. (Content extraction) Which sentences in the note describe the history treatment plan for the patient?
# 11. (Text Summarization) Provide a brief summary of the future treatment plan for the patient?
# 12. (Content extraction) Which sentences in the note describe the future treatment plan for the patient?
# 13. (Content extraction) What medications are the patient currently on?
# 14. (Text Summarization) List all the diagnoses and determine whether they are from recent onsite visits or past medical history.
# 15. (Question Answering) What is the patient's chief complaint?
# 16. (Natural Language Generation) Can you generate a brief summary of the patient's medical history?
# 17. (Text Summarization) Can you summarize the imaging/studies section of the discharge summary?
# 18. (Text Classification) Is the patient's mental status considered normal or abnormal?
# 19. (Temporal Information Extraction) When was the patient's most recent discharge from the hospital?
# 20. (Relation Extraction) Is there any relation between the patient's RLE pain and her Alzheimer's dementia?
# 21. (Named Entity Recognition) Can you identify all of the patient's medical conditions mentioned in the discharge summary?
# 22. (Paraphrasing) Can you rephrase the sentence "Given her age, risk of fall, and her new intracranial lesion (high risk for venous bleed), anticoagulation was deferred"?
# 23. (Clinical Concept Normalization) Can you normalize the medical abbreviation "AFib" to its full form?
# 24. (Keyword Extraction) What are the most frequently mentioned symptoms in the discharge summary?
# 25. (Abbreviation Expansion) Can you expand the abbreviation "IVC" to its full form?
# 26. (Feature Extraction) What are the key features of the patient's medical history that may be relevant to her RLE DVT?
# 27. (Content Extraction) Can you extract all of the medications prescribed to the patient upon discharge?
# 28. (Text Classification) Was the patient's UA grossly positive or negative?
# 29. (Question Answering) What is the patient's CHADSVASC score?
# 30. (Relation Extraction) Is there any relation between the patient's chronic HCV and her RLE DVT?
# ```
# try get_completion...
# Success! get_completion() completed. tried 0
# -----------------------------------------
# {
#     "qas": [
#         {
#             "id": 1,
#             "question": "(Text Summarization) What is the patient's primary diagnosis?",
#             "answers": [
#                 "RLE DVT"
#             ]
#         },
#         {
#             "id": 2,
#             "question": "(Content extraction) Which sentences in the note describe the diagnosis?",
#             "answers": [
#                 "Ms. ___ is a ___ PMHx advanced Alzheimer's dementia, chronic  HCV, autoimmune hepatitis, and AFib who presents from her SNF  for RLE DVT.",
#                 "Per report from her SNF, the patient had been complaining of RLE  pain.",
#                 "LENIs showed DVT after which the patient was transferred  to ___."
#             ]
#         },
#         {
#             "id": 3,
#             "question": "(Text Summarization) What are the comorbidities of the patient?",
#             "answers": [
#                 "advanced Alzheimer's dementia, chronic HCV, autoimmune hepatitis, and AFib",
#                 "HTN",
#                 "atypical meningioma"
#             ]
#         },
#         {
#             "id": 4,
#             "question": "(Content extraction) Which sentences in the note describe the comorbidities?",
#             "answers": [
#                 "Ms. ___ is a ___ PMHx advanced Alzheimer's dementia, chronic  HCV, autoimmune hepatitis, and AFib who presents from her SNF  for RLE DVT.",
#                 "- Alzheimer's; ADL impaired in preparing food, remembering to  bathe, recalling faces.",
#                 "HCV, chronic, low viral load (last in OMR ___, 15 million  copies)",
#                 "Autoimmune hepatitis",
#                 "HTN - atypical meningioma"
#             ]
#         },
#         {
#             "id": 5,
#             "question": "(Named Entity Recognition) List all the medications mentioned in the discharge summary.",
#             "answers": [
#                 "Aspirin 81 mg PO DAILY",
#                 "Donepezil 10 mg PO QHS",
#                 "LevETIRAcetam 500 mg PO BID",
#                 "Memantine 21 mg PO DAILY",
#                 "Multivitamins W/minerals 1 TAB PO DAILY",
#                 "NIFEdipine CR 30 mg PO DAILY",
#                 "PredniSONE 5 mg PO DAILY",
#                 "Vitamin E 400 UNIT PO DAILY",
#                 "IV ceftriaxone",
#                 "Lovenox 70 mg x 1"
#             ]
#         },
#         {
#             "id": 6,
#             "question": "(Content extraction) Which sentences in the note describe the medications?",
#             "answers": [
#                 "She was given IV  ceftriaxone, Lovenox 70 mg x 1 prior to transfer.",
#                 "Discharge Medications: 1. Aspirin 81 mg PO DAILY  2. Donepezil 10 mg PO QHS  3. LevETIRAcetam 500 mg PO BID  4. Memantine 21 mg PO DAILY  5. Multivitamins W/minerals 1 TAB PO DAILY  6. NIFEdipine CR 30 mg PO DAILY  7. PredniSONE 5 mg PO DAILY  8. Vitamin E 400 UNIT PO DAILY"
#             ]
#         },
#         {
#             "id": 7,
#             "question": "(Named Entity Recognition) List all the labs mentioned in the discharge summary.",
#             "answers": [
#                 "GLUCOSE-94",
#                 "UREA N-10",
#                 "CREAT-0.8",
#                 "SODIUM-141",
#                 "POTASSIUM-4.7",
#                 "CHLORIDE-102",
#                 "TOTAL CO2-26",
#                 "ANION GAP-18",
#                 "LACTATE-1.5",
#                 "WBC-7.6",
#                 "RBC-4.63",
#                 "HGB-12.8",
#                 "HCT-41.0",
#                 "MCV-89",
#                 "MCH-27.6",
#                 "MCHC-31.2",
#                 "RDW-14.5",
#                 "RDWSD-46.3",
#                 "NEUTS-56.1",
#                 "MONOS-10.4",
#                 "EOS-1.6",
#                 "BASOS-0.4",
#                 "AbsNeut-4.28",
#                 "AbsLymp-2.37",
#                 "AbsMono-0.79",
#                 "AbsEos-0.12",
#                 "AbsBaso-0.03",
#                 "PLT COUNT-178",
#                 "PTT-32.0",
#                 "URINE  COLOR-Yellow",
#                 "APPEAR-Clear",
#                 "SP ___",
#                 "URINE  BLOOD-NEG",
#                 "NITRITE-NEG",
#                 "PROTEIN-TR",
#                 "GLUCOSE-NEG",
#                 "KETONE-NEG",
#                 "BILIRUBIN-NEG",
#                 "UROBILNGN-2",
#                 "PH-7.0",
#                 "LEUK-LG",
#                 "URINE  RBC-2",
#                 "WBC-21",
#                 "BACTERIA-FEW",
#                 "YEAST-NONE",
#                 "EPI-<1",
#                 "CXR",
#                 "OSH ___",
#                 "RLE DVT"
#             ]
#         },
#         {
#             "id": 8,
#             "question": "(Content extraction) Which sentences in the note describe the labs?",
#             "answers": [
#                 "ADMISSION LABS ============== ___ 11:00PM   GLUCOSE-94 UREA N-10 CREAT-0.8 SODIUM-141  POTASSIUM-4.7 CHLORIDE-102 TOTAL CO2-26 ANION GAP-18 ___ 11:00PM   LACTATE-1.5 ___ 11:00PM   WBC-7.6 RBC-4.63 HGB-12.8 HCT-41.0 MCV-89  MCH-27.6 MCHC-31.2* RDW-14.5 RDWSD-46.3 ___ 11:00PM   NEUTS-56.1 ___ MONOS-10.4 EOS-1.6  BASOS-0.4 IM ___ AbsNeut-4.28 AbsLymp-2.37 AbsMono-0.79  AbsEos-0.12 AbsBaso-0.03 ___ 11:00PM   PLT COUNT-178 ___ 11:00PM   ___ PTT-32.0 ___ ___ 10:00PM URINE  COLOR-Yellow APPEAR-Clear SP ___ ___ 10:00PM URINE  BLOOD-NEG NITRITE-NEG PROTEIN-TR  GLUCOSE-NEG KETONE-NEG BILIRUBIN-NEG UROBILNGN-2* PH-7.0 LEUK-LG ___ 10:00PM URINE  RBC-2 WBC-21* BACTERIA-FEW YEAST-NONE  EPI-<1  IMAGING/STUDIES =============== ___ CXR No evidence of pneumonia. OSH ___ RLE DVT FINDINGS 1. Patent normal sized, non-duplicated IVC with single bilateral  renal veins and no evidence of a clot. 2. Successful deployment of an infra-renal permanent infrarenal  IVC filter. IMPRESSION Successful deployment of permanent infrarenal IVC filter."
#             ]
#         },
#         {
#             "id": 9,
#             "question": "(Text Summarization) Provide a brief summary of the history treatment plan for the patient?",
#             "answers": [
#                 "Ms. ___ was admitted for RLE DVT. She had a history of advanced Alzheimer's dementia, chronic HCV, autoimmune hepatitis, AFib, HTN, and an atypical meningioma. Her initial labs were unremarkable and she was given IV ceftriaxone and Lovenox 70 mg x 1 prior to transfer. Upon arrival, she was started on aspirin, Donepezil, LevETIRAcetam, Memantine, Multivitamins W/minerals, NIFEdipine CR, PredniSONE, and Vitamin E. She had a successful deployment of permanent infrarenal IVC filter. She was discharged in a confused mental status but alert and interactive."
#             ]
#         },
#         {
#             "id": 10,
#             "question": "(Content extraction) Which sentences in the note describe the history treatment plan for the patient?",
#             "answers": [
#                 "Ms. ___ was admitted for RLE DVT. She had a history of advanced Alzheimer's dementia, chronic HCV, autoimmune hepatitis, AFib, HTN, and an atypical meningioma.",
#                 "Her initial labs were unremarkable and she was given IV ceftriaxone and Lovenox 70 mg x 1 prior to transfer.",
#                 "Upon arrival, she was started on aspirin, Donepezil, LevETIRAcetam, Memantine, Multivitamins W/minerals, NIFEdipine CR, PredniSONE, and Vitamin E.",
#                 "She had a successful deployment of permanent infrarenal IVC filter.",
#                 "She was discharged in a confused mental status but alert and interactive."
#             ]
#         }
#     ]
# }
# -----------------------------------------
#     Success! json.loads() completed. tried 0
# 10
# try get_completion...
# Success! get_completion() completed. tried 0
# -----------------------------------------
# {
#   "qas": [
#     {
#       "answers": [
#         "Aspirin 81 mg PO DAILY, Donepezil 10 mg PO QHS, LevETIRAcetam 500 mg PO BID, Memantine 21 mg PO DAILY, Multivitamins W/minerals 1 TAB PO DAILY, NIFEdipine CR 30 mg PO DAILY, PredniSONE 5 mg PO DAILY, Vitamin E 400 UNIT PO DAILY"
#       ],
#       "id": "13",
#       "question": "(Content extraction) What medications are the patient currently on?"
#     },
#     {
#       "answers": [
#         "Ms. ___ had an IVC filter placed and was started on anticoagulation therapy, and will be discharged on multiple medications including aspirin, LevETIRAcetam, Memantine, NIFEdipine, PredniSONE, and Vitamin E."
#       ],
#       "id": "11",
#       "question": "(Text Summarization) Provide a brief summary of the future treatment plan for the patient?"
#     },
#     {
#       "answers": [
#         "Successful deployment of permanent infrarenal IVC filter."
#       ],
#       "id": "17",
#       "question": "(Text Summarization) Can you summarize the imaging/studies section of the discharge summary?"
#     },
#     {
#       "answers": [
#         "Alzheimer's dementia, chronic HCV, autoimmune hepatitis, AFib, RLE DVT, atypical meningioma"
#       ],
#       "id": "14",
#       "question": "(Text Summarization) List all the diagnoses and determine whether they are from recent onsite visits or past medical history."
#     },
#     {
#       "answers": [
#         "RLE pain"
#       ],
#       "id": "15",
#       "question": "(Question Answering) What is the patient's chief complaint?"
#     },
#     {
#       "answers": [
#         "Ms. ___ is an elderly female with a past medical history of Alzheimer's dementia, chronic HCV, autoimmune hepatitis, AFib, and atypical meningioma, who presented with RLE pain and was found to have a DVT. She had an IVC filter placed and was started on anticoagulation therapy, and will be discharged on multiple medications including aspirin, LevETIRAcetam, Memantine, NIFEdipine, PredniSONE, and Vitamin E."
#       ],
#       "id": "16",
#       "question": "(Natural Language Generation) Can you generate a brief summary of the patient's medical history?"
#     },
#     {
#       "answers": [
#         "Mental Status Confused - always."
#       ],
#       "id": "18",
#       "question": "(Text Classification) Is the patient's mental status considered normal or abnormal?"
#     },
#     {
#       "answers": [
#         "She was most recently discharged from the hospital for seizure activity, but the date of discharge is not specified."
#       ],
#       "id": "19",
#       "question": "(Temporal Information Extraction) When was the patient's most recent discharge from the hospital?"
#     },
#     {
#       "answers": [
#         "It is unclear from the note whether there is a relation between the patient's RLE pain and her Alzheimer's dementia."
#       ],
#       "id": "20",
# ...
#   File "/Users/sinianzhang/opt/anaconda3/lib/python3.9/site-packages/openai/api_resources/abstract/engine_api_resource.py", line 153, in create
#     response, _, api_key = requestor.request(
#   File "/Users/sinianzhang/opt/anaconda3/lib/python3.9/site-packages/openai/api_requestor.py", line 230, in request
#     resp, got_stream = self._interpret_response(result, stream)
#   File "/Users/sinianzhang/opt/anaconda3/lib/python3.9/site-packages/openai/api_requestor.py", line 624, in _interpret_response
#     self._interpret_response_line(
#   File "/Users/sinianzhang/opt/anaconda3/lib/python3.9/site-packages/openai/api_requestor.py", line 687, in _interpret_response_line
#     raise self.handle_error_response(
# openai.error.RateLimitError: Requests to the Creates a completion for the chat message Operation under Azure OpenAI API version 2023-03-15-preview have exceeded token rate limit of your current OpenAI S0 pricing tier. Please retry after 4 seconds. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit.
# try get_completion...
# Success! get_completion() completed. tried 1
# -----------------------------------------
# {
#   "qas": [
#     {
#       "answers": [
#         "shortness of breath, clamminess, lung pain, back pain, weakness in lower extremities"
#       ],
#       "id": "21",
#       "question": "(Keyword Extraction) What are the main symptoms the patient reported?"
#     },
#     {
#       "answers": [
#         "shortness of breath"
#       ],
#       "id": "22",
#       "question": "(Abbreviation Expansion) What does \"SOB\" stand for?"
#     },
#     {
#       "answers": [
#         "Hypercoagulable workup with Factor V Leiden Deficiency"
#       ],
#       "id": "23",
#       "question": "(Feature Extraction) What treatment plan was recommended for the patient's hypercoagulable workup?"
#     },
#     {
#       "answers": [
#         "Home oxygen requirement for sleep and ambulation"
#       ],
#       "id": "24",
#       "question": "(Content Extraction) What is the patient's current oxygen requirement?"
#     },
#     {
#       "answers": [
#         "Primary Diagnosis Pulmonary embolism (bilateral), Lower extremity DVT"
#       ],
#       "id": "25",
#       "question": "(Text Classification) What is the patient's discharge diagnosis?"
#     },
#     {
#       "answers": [
#         "no"
#       ],
#       "id": "27",
#       "question": "(Yes/No Question) Does the patient have a history of hypertension or hypertensive crisis?"
#     },
#     {
#       "answers": [
#         "The patient's mother has a history of recurrent DVT's and the patient's father has a history of recurrent DVT's."
#       ],
#       "id": "28",
#       "question": "(Open-Ended Question) Can you provide more information about the patient's family history of DVTs?"
#     },
#     {
#       "answers": [
#         "Metformin"
#       ],
#       "id": "29",
#       "question": "(Multiple-Choice Question) Which medication was held for the patient's Type II Diabetes?\na. ISS\nb. Lantus\nc. Humalog\nd. Metformin"
#     },
#     {
#       "answers": [
#         "lung pain that he refers to has \"lung pain\" that he rates at ___ that started at the same time as his shortness of breath and claminess yesterday evening"
#       ],
#       "id": "30",
#       "question": "(Paraphrasing) Can you rephrase the patient's report of \"lung pain\" in medical terminology?"
#     }
#   ]
# }
# -----------------------------------------
#     Success! json.loads() completed. tried 0
#     Error! Answer additional questions. 9 questions generated, 10 expected. Retrying...
# try get_completion...
# Success! get_completion() completed. tried 0
# -----------------------------------------
# {
#     "qas": [
#         {
#             "answers": [
#                 "suddenly SOB, sweaty, and clammy, shortness of breath, back pain, weakness in both lower extremities"
#             ],
#             "id": "21",
#             "question": "(Keyword Extraction) What are the main symptoms the patient reported?"
#         },
#         {
#             "answers": [
#                 "Shortness of breath"
#             ],
#             "id": "22",
#             "question": "(Abbreviation Expansion) What does \"SOB\" stand for?"
#         },
#         {
#             "answers": [
#                 "Hypercoagulable workup with Factor V Leiden Deficiency and antiphospholipid syndrome"
#             ],
#             "id": "23",
#             "question": "(Feature Extraction) What treatment plan was recommended for the patient's hypercoagulable workup?"
#         },
#         {
#             "answers": [
#                 "Home oxygen requirement for sleep and ambulation"
#             ],
#             "id": "24",
#             "question": "(Content Extraction) What is the patient's current oxygen requirement?"
#         },
#         {
#             "answers": [
#                 "Primary Diagnosis: Pulmonary embolism (bilateral), Lower extremity DVT. Secondary: Hyperlipidemia, Type I Diabetes, chronic lower back pain"
#             ],
#             "id": "25",
#             "question": "(Text Classification) What is the patient's discharge diagnosis?"
#         },
#         {
#             "answers": [
#                 "No"
#             ],
#             "id": "27",
#             "question": "(Yes/No Question) Does the patient have a history of hypertension or hypertensive crisis?"
#         },
#         {
#             "answers": [
#                 "The patient's mother has a history of recurrent DVT's, as well as recurrent DVT's in father."
#             ],
#             "id": "28",
#             "question": "(Open-Ended Question) Can you provide more information about the patient's family history of DVTs?"
#         },
#         {
#             "answers": [
#                 "Metformin"
#             ],
#             "id": "29",
#             "question": "(Multiple-Choice Question) Which medication was held for the patient's Type II Diabetes?\na. ISS\nb. Lantus\nc. Humalog\nd. Metformin"
#         },
#         {
#             "answers": [
#                 "The patient refers to his back pain as \"lung pain\""
#             ],
#             "id": "30",
#             "question": "(Paraphrasing) Can you rephrase the patient's report of \"lung pain\" in medical terminology?"
#         }
#     ]
# }
# -----------------------------------------
#     Success! json.loads() completed. tried 1
#     Error! Answer additional questions. 9 questions generated, 10 expected. Retrying...
# try get_completion...
# Success! get_completion() completed. tried 0
# -----------------------------------------
# {
#   "qas": [
#     {
#       "answers": [
#         "suddenly SOB, sweaty, and clammy, shortness of breath, back pain, weakness in both lower extremities"
#       ],
#       "id": "21",
#       "question": "(Keyword Extraction) What are the main symptoms the patient reported?"
#     },
#     {
#       "answers": [
#         "shortness of breath"
#       ],
#       "id": "22",
#       "question": "(Abbreviation Expansion) What does \"SOB\" stand for?"
#     },
#     {
#       "answers": [
#         "Hypercoagulable workup with Factor V Leiden and antiphospholipid syndrome"
#       ],
#       "id": "23",
#       "question": "(Feature Extraction) What treatment plan was recommended for the patient's hypercoagulable workup?"
#     },
#     {
#       "answers": [
#         "Home oxygen requirement for sleep and ambulation"
#       ],
#       "id": "24",
#       "question": "(Content Extraction) What is the patient's current oxygen requirement?"
#     },
#     {
#       "answers": [
#         "Primary Diagnosis Pulmonary embolism (bilateral), Lower extremity DVT\nSecondary Hyperlipidemia, Type I Diabetes, chronic lower back pain"
#       ],
#       "id": "25",
#       "question": "(Text Classification) What is the patient's discharge diagnosis?"
#     },
#     {
#       "answers": [
#         "No"
#       ],
#       "id": "27",
#       "question": "(Yes/No Question) Does the patient have a history of hypertension or hypertensive crisis?"
#     },
#     {
#       "answers": [
#         "Recurrent DVT's in mother as well as recurrent DVT's in father"
#       ],
#       "id": "28",
#       "question": "(Open-Ended Question) Can you provide more information about the patient's family history of DVTs?"
#     },
#     {
#       "answers": [
#         "Metformin"
#       ],
#       "id": "29",
#       "question": "(Multiple-Choice Question) Which medication was held for the patient's Type II Diabetes?\na. ISS\nb. Lantus\nc. Humalog\nd. Metformin"
#     },
#     {
#       "answers": [
#         "Pain in his lungs"
#       ],
#       "id": "30",
#       "question": "(Paraphrasing) Can you rephrase the patient's report of \"lung pain\" in medical terminology?"
#     }
#   ]
# }
# -----------------------------------------
#     Success! json.loads() completed. tried 2
#     Error! Answer additional questions. 9 questions generated, 10 expected. Retrying...
# try get_completion...
# -----------------------------------------
# get_completion Error: Requests to the Creates a completion for the chat message Operation under Azure OpenAI API version 2023-03-15-preview have exceeded token rate limit of your current OpenAI S0 pricing tier. Please retry after 1 second. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit.
# -----------------------------------------
# Error occurred in get_completion(), retrying (try 1)...
# Traceback (most recent call last):
#   File "/var/folders/nt/61qr68k1095348fy48d1yhf80000gp/T/ipykernel_37696/2648004828.py", line 39, in get_completion
#     response = openai.ChatCompletion.create(
#   File "/Users/sinianzhang/opt/anaconda3/lib/python3.9/site-packages/openai/api_resources/chat_completion.py", line 25, in create
#     return super().create(*args, **kwargs)
#   File "/Users/sinianzhang/opt/anaconda3/lib/python3.9/site-packages/openai/api_resources/abstract/engine_api_resource.py", line 153, in create
#     response, _, api_key = requestor.request(
#   File "/Users/sinianzhang/opt/anaconda3/lib/python3.9/site-packages/openai/api_requestor.py", line 230, in request
#     resp, got_stream = self._interpret_response(result, stream)
#   File "/Users/sinianzhang/opt/anaconda3/lib/python3.9/site-packages/openai/api_requestor.py", line 624, in _interpret_response
#     self._interpret_response_line(
#   File "/Users/sinianzhang/opt/anaconda3/lib/python3.9/site-packages/openai/api_requestor.py", line 687, in _interpret_response_line
#     raise self.handle_error_response(
# openai.error.RateLimitError: Requests to the Creates a completion for the chat message Operation under Azure OpenAI API version 2023-03-15-preview have exceeded token rate limit of your current OpenAI S0 pricing tier. Please retry after 1 second. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit.
# try get_completion...
# Success! get_completion() completed. tried 1
# -----------------------------------------
# {
#   "qas": [
#     {
#       "answers": [
#         "shortness of breath, clamminess, back pain, weakness in both lower extremities"
#       ],
#       "id": "21",
#       "question": "(Keyword Extraction) What are the main symptoms the patient reported?"
#     },
#     {
#       "answers": [
#         "Shortness of Breath"
#       ],
#       "id": "22",
#       "question": "(Abbreviation Expansion) What does \"SOB\" stand for?"
#     },
#     {
#       "answers": [
#         "Hypercoagulable workup with Factor V Leiden deficiency and antiphospholipid syndrome."
#       ],
#       "id": "23",
#       "question": "(Feature Extraction) What treatment plan was recommended for the patient's hypercoagulable workup?"
#     },
#     {
#       "answers": [
#         "Home oxygen requirement for sleep and ambulation."
#       ],
#       "id": "24",
#       "question": "(Content Extraction) What is the patient's current oxygen requirement?"
#     },
#     {
#       "answers": [
#         "Primary Diagnosis Pulmonary embolism (bilateral), Lower extremity DVT."
#       ],
#       "id": "25",
#       "question": "(Text Classification) What is the patient's discharge diagnosis?"
#     },
#     {
#       "answers": [
#         "No"
#       ],
#       "id": "27",
#       "question": "(Yes/No Question) Does the patient have a history of hypertension or hypertensive crisis?"
#     },
#     {
#       "answers": [
#         "The patient's mother has a history of recurrent DVT's as well as recurrent DVT's in father."
#       ],
#       "id": "28",
#       "question": "(Open-Ended Question) Can you provide more information about the patient's family history of DVTs?"
#     },
#     {
#       "answers": [
#         "Metformin"
#       ],
#       "id": "29",
#       "question": "(Multiple-Choice Question) Which medication was held for the patient's Type II Diabetes?\na. ISS\nb. Lantus\nc. Humalog\nd. Metformin"
#     },
#     {
#       "answers": [
#         "Pain in the lungs rated at ___ that started at the same time as his shortness of breath and clamminess yesterday evening."
#       ],
#       "id": "30",
#       "question": "(Paraphrasing) Can you rephrase the patient's report of \"lung pain\" in medical terminology?"
#     }
#   ]
# }
# -----------------------------------------
#     Success! json.loads() completed. tried 3
#     Error! Answer additional questions. 9 questions generated, 10 expected. Retrying...
# try get_completion...
# Success! get_completion() completed. tried 0
# -----------------------------------------
# {
#   "qas": [
#     {
#       "question": "(Keyword Extraction) What are the main symptoms the patient reported?",
#       "id": 21,
#       "answers": [
#         "The main symptoms the patient reported were sudden onset of shortness of breath (SOB), sweating, and clamminess, as well as lung pain and weakness in both lower extremities."
#       ]
#     },
#     {
#       "question": "(Abbreviation Expansion) What does 'SOB' stand for?",
#       "id": 22,
#       "answers": [
#         "SOB stands for shortness of breath."
#       ]
#     },
#     {
#       "question": "(Feature Extraction) What treatment plan was recommended for the patient's hypercoagulable workup?",
#       "id": 23,
#       "answers": [
#         "The plan for outpatient follow up with Hem/Onc was recommended to address hypercoagulable workup with Factor V Leiden and antiphospholipid syndrome."
#       ]
#     },
#     {
#       "question": "(Content Extraction) What is the patient's current oxygen requirement?",
#       "id": 24,
#       "answers": [
#         "The patient was discharged with home oxygen requirement for sleep and ambulation."
#       ]
#     },
#     {
#       "question": "(Text Classification) What is the patient's discharge diagnosis?",
#       "id": 25,
#       "answers": [
#         "The patient's discharge diagnosis includes primary diagnosis of bilateral pulmonary embolism and lower extremity DVT, and secondary diagnosis of hyperlipidemia, type I diabetes, and chronic lower back pain."
#       ]
#     },
#     {
#       "question": "(Named Entity Recognition) Has the patient experienced any surgeries in the past?",
#       "id": 26,
#       "answers": [
#         "The patient denies any history of surgery in the last 2 months."
#       ]
#     },
#     {
#       "question": "(Yes/No Question) Does the patient have a history of hypertension or hypertensive crisis?",
#       "id": 27,
#       "answers": [
#         "The patient denies any history of hypertension or hypertensive crisis."
#       ]
#     },
#     {
#       "question": "(Open-Ended Question) Can you provide more information about the patient's family history of DVTs?",
#       "id": 28,
#       "answers": [
#         "The patient's family history includes recurrent DVTs in both the mother and father."
#       ]
#     },
#     {
#       "question": "(Multiple-Choice Question) Which medication was held for the patient's Type II Diabetes?\na. ISS\nb. Lantus\nc. Humalog\nd. Metformin",
#       "id": 29,
#       "answers": [
#         "Metformin was held for the patient's Type II Diabetes."
#       ]
#     },
#     {
#       "question": "(Paraphrasing) Can you rephrase the patient's report of 'lung pain' in medical terminology?",
#       "id": 30,
#       "answers": [
#         "The patient reported back pain that he referred to as 'lung pain', which he rated at an intensity level of ___."
#       ]
#     }
#   ]
# }
# -----------------------------------------
#     Success! json.loads() completed. tried 4
# 30
# 30

# %%
print("The number of tokens: ",num_tokens)
# Out:
# The number of tokens:  175734

# %%
section = [
        "Allergies",
        "Attending",
        "History of Present Illness",
        "Past Medical History",
        "Social History",
        "Physical Exam",
        "Brief Hospital Course",
        "Medications on Admission",
        "Discharge Disposition"
]

# %%
temp = NotesSections["10053872-DS-7"][NotesSections["10053872-DS-7"]['label'].isin(section)]

# %%
''.join(temp['temp'])
# Out:
# 'Allergies: Sulfa (Sulfonamides) / Erythromycin BaseAttending: ___.History of Present Illness: Patient is a ___ year old female status post uterine artery  fibroid embolization by ___ on ___ who was discharged ___ and  around midnight awoke with right groin pain. The patient noticed  that her right groin appeared swollen and felt slightly firm.  This area of swelling seemed to increase in size. The patient  also felt pain radiating across her lower abdomen, causing her  to "double over in pain." She also felt it difficult to  straighten her right leg without pain. She called the  interventional radiology physician\'s assistant, who instructed  her to come to the emergency department.  In the ED, patient was found by ultrasound to have a right groin  pseudoaneurysm. Patient was admitted for thrombin injection of  pseudoaneurysm.  On the floor, patient reported right groin pain of ___. She had  no other complaints. Review of sytems (+) Per HPI (-) Denies fever, chills, night sweats, recent weight loss or  gain. Denies headache, sinus tenderness, rhinorrhea or  congestion. Denied cough, shortness of breath. Denied chest pain  or tightness, palpitations. Denied nausea, vomiting, diarrhea,  constipation or abdominal pain. No recent change in bowel or  bladder habits. No dysuria.Past Medical History: 1. Rheumatoid Arthrits 2. Irritable Bowel Syndrome 3. Bicuspid aortic valve (no TTE in chart).  Past Surgical History 1. Bilateral knee arthroscopy 2. Bilateral ___ Metatarsal surgerySocial History: ___Physical Exam:  Vitals T: 98.4 BP:96/60 P: 63 R:18 O2: 98 RA General Alert, oriented, no acute distress HEENT Sclera anicteric, MMM, oropharynx clear Neck supple, JVP not elevated, no LAD Lungs Clear to auscultation bilaterally, no wheezes, rales,  ronchi CV Regular rate and rhythm, normal S1 + S2, no murmurs, rubs,  gallops Abdomen soft, non-tender, non-distended, bowel sounds present,  no rebound tenderness or guarding, no organomegaly Ext Warm, well perfused, 2+ pulses, no clubbing, cyanosis or  edema Right Groin Appears slightly swollen, no erythema, +bruit  auscultated, +tenderness to palpation.Brief Hospital Course: This is a ___ year old female with uterine fibroid embolization  on ___ who presented with right groin pain and swelling  determined by ultrasound to be a pseudoaneurysm.  1) Pseudoaneurysm: Patient presented with psuedoaneurysm  confirmed by ultrasound that was secondary to her recent uterine  fibroid embolization on ___. On ___ patient underwent  psuedoaneurysm thrombin injection. Ultrasound on ___ indicated  pseudoaneurysm had been thrombosed with remaining femoral artery  patent. A repeat US on ___ prior to discharge also demonstrated  thrombosed right femoral artery  pseudoaneurysm and patent right common and superficial femoral  arteries and veins. Following thrombin injection patient  experienced right groin pain. She also experienced pain in her  pelvic region thought to be secondary to fibroids responding to  embolization procedure. Pain initially treated with intravenous  morphine and transitioned to oral oxycodone at time of  discharge. She was given a prescription for oxycodone 5mg ___  tabs TID as needed for pain. She was instructed not to drive or  operate heavy machinery while taking this medication. She was  also prescribed ibuprofen 800 mg PO TID to reduce inflammation  and instructed to take this medication with food and water.  Post-procedure follow up to be arranged by ___,  interventional radiology ___.  2) Constipation: Patient experienced constipation during this  admission. Last bowel movement day prior to admission. Patient  reports that she has irritable bowel syndrome with constipation  at baseline. Likely constipation worsened due to patient taking  narcotics for pain control. Patient started on bowel regimen  including colace, senna and lactulose. Patient was discharged  with a prescription for oral lactulose. She will contact her  primary care physician if she is unable to have a bowel movem ...

# %%
len(tokenizer.tokenize(''.join(temp['temp'])))
# Out:
# 1314
